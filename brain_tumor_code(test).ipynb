# %%
from tensorflow.keras.models import load_model
model = load_model(r"C:/Users/Maiz/Documents/brain_tumor/braintumormodel.keras")

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import numpy as np
# Function to make predictions on new images
def load_and_preprocess_image(img_path):
    img = image.load_img(img_path, target_size=(150, 150))
    img_array = image.img_to_array(img) / 255.0  # Normalize pixel values
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    return img_array

# %%
# Example usage for prediction
image_path = 'C:/Users/Maiz/Documents/brain_tumor/Testing/no_tumor/image(1).jpg'  # Replace with your image path
processed_image = load_and_preprocess_image(image_path)
predictions = model.predict(processed_image)

# Get the predicted class
predicted_class_index = np.argmax(predictions[0])  # Get the index of the highest probability
categories = ['glioma tumor', 'meningioma tumor', 'no tumor', 'pituitary tumor']
predicted_class = categories[predicted_class_index]
print(f'Predicted Class: {predicted_class}')

# Plot the image and the predicted class
plt.imshow(image.load_img(image_path, target_size=(150, 180)))  # Load the original image for plotting
plt.title(f'Predicted Class: {predicted_class}')
plt.axis('off')  # Hide axes
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: no tumor
